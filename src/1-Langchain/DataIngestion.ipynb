# %%
 ## Text Loader
from langchain_community.document_loaders import TextLoader
loader=TextLoader('speech.txt')
loader

# %%
text_document=loader.load()
text_document
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='Since you left the request wide open, I have curated a "Tasting Menu" of Information across a few different fields. Here are three fascinating bite-sized topics to spark your interest:\n\n1. ðŸŒŒ The "Smell" of Space\nWhile space is a vacuum, astronauts returning from spacewalks consistently report a distinct odor clinging to their suits and equipment.\n\nThe Scent: They describe it as seared steak, hot metal, or welding fumes.\n\nThe Cause: This is likely caused by polycyclic aromatic hydrocarbons (PAHs)â€”high-energy particles that are formed in the death throes of stars. When astronauts re-enter the airlock, these particles react with oxygen, creating that distinct burnt smell.')]

# %% [markdown]
# ## Reading a PDF File

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader('assest.pdf')
docs = loader.load()
